# %%
import pandas as pd

# %%
df = pd.read_csv("LetterboxMovieClassificationDataset.csv")
print(df.info) 
print(df.head())
# Out:
# <bound method DataFrame.info of       Unnamed: 0           Film_title           Director  Average_rating  \
# 0              0              The Fan    Eckhart Schmidt        3.570000
# 1              1   Mad Max: Fury Road      George Miller        4.180000
# 2              2             Suspiria      Dario Argento        3.930000
# 3              3  Lost in Translation      Sofia Coppola        3.790000
# 4              4                Akira    Katsuhiro Otomo        4.280000
# ...          ...                  ...                ...             ...
# 9995        9997      Evil Never Dies           Uli Edel        3.268535
# 9996        9998   The Master Butcher           Uli Edel        3.268535
# 9997        9999      Unterm Birnbaum           Uli Edel        3.268535
# 9998       10000             Simulant       April Mullen        2.260000
# 9999       10001             Roujin Z  Hiroyuki Kitakubo        3.590000
#
# ...

# %% [markdown]
# 1. Film mana yang memiliki rating rata-rata tertinggi?
#
# 2. Siapa sutradara paling populer berdasarkan total "likes" atau jumlah film yang muncul?
#
# 3. Apa saja genre paling sering muncul di dataset?
#
# 4. Apa bahasa asli paling umum dari film-film ini?
#
# 5. Berapa rata-rata durasi (runtime) film dari genre tertentu seperti "Drama" atau "Horror"?
