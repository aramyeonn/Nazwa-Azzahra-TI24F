# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
try:
    df = pd.read_csv("ai_adoption_dataset.csv")
    df = df.head(100)  # ambil 100 data awal agar lebih ringan
    print(df)
except FileNotFoundError:
    print("File not found")
# Out:
#       country        industry           ai_tool  adoption_rate  \
# 0         USA      Technology           ChatGPT          40.45
# 1      France   Manufacturing        Midjourney          35.72
# 2   Australia  Transportation           ChatGPT          13.47
# 3          UK   Manufacturing           ChatGPT          48.46
# 4          UK     Agriculture  Stable Diffusion          34.06
# ..        ...             ...               ...            ...
# 95      China     Agriculture  Stable Diffusion          85.34
# 96      China     Agriculture        Midjourney          86.45
# 97  Australia   Manufacturing        Midjourney          29.51
# 98  Australia  Transportation        Midjourney          64.96
# 99      India          Retail           ChatGPT          58.54
#
#     daily_active_users  year  \
# 0                 2461  2023
# 1                 8496  2024
# 2                 8641  2024
# 3                 3488  2023
# 4                 1124  2024
# ...

# %%
X = df['daily_active_users'].values.reshape(-1, 1)
y = df['adoption_rate'].values

# Buat model regresi linear
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# Plot hasil
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', alpha=0.6, label='Data Asli')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regresi Linear')
plt.xlabel('User Aktif Sehari-hari')
plt.ylabel('Adoption Rate (%)')
plt.title('User Aktif Sehari-hari vs Adoption Rate')
plt.legend(loc='upper right')  # hindari warning loc="best"
plt.grid(True)
plt.tight_layout()
plt.show()
